# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("car_dataset.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0 Company Names            Cars Names      Engines  \
# 0           0       FERRARI         SF90 STRADALE           V8
# 1           1   ROLLS ROYCE               PHANTOM          V12
# 2           2          Ford                   KA+  1.2L Petrol
# 3           3      MERCEDES               GT 63 S           V8
# 4           4          AUDI            AUDI R8 Gt          V10
# 5           5           BMW          Mclaren 720s           V8
# 6           6  ASTON MARTIN            VANTAGE F1           V8
# 7           7       BENTLEY  Continental GT Azure           V8
# 8           8   LAMBORGHINI       VENENO ROADSTER          V12
# 9           9       FERRARI            F8 TRIBUTO           V8
#
#    Battery Capacity (cc)  HorsePower  Total Speed (km/h)  \
# 0                 3990.0       963.0                 340
# 1                 6749.0       563.0                 250
# 2                 1200.0        77.5                 165
# ...

# %%
sns.lineplot(x="Battery Capacity (cc)",y="Price ($)",data=df)
# Out:
# <Axes: xlabel='Battery Capacity (cc)', ylabel='Price ($)'>
